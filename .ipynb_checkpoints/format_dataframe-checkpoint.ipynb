# %%
import pandas as pd
import os
from IPython.display import HTML

best_brawlers = 8

df = pd.read_csv('maps/best_brawlers.csv')

def clean_brawler_name(brawler):
    if brawler=='8-Bit':
        return brawler
    elif brawler=='Mr.P':
        return 'Mr. P'
    else:
        return brawler.replace('-',' ')
    
def clean_string(s):
    s = s.split(', ')
    s = [(x.replace('%','')) for x in s]
    return ', '.join(s)

def round_string(s):
    s = s.split(', ')
    s = [str(int(float(x))) for x in s]
    return ', '.join(s)
    
def nth_repl(s, sub, repl, n):
    find = s.find(sub)
    # If find is not -1 we have found at least one match for the substring
    i = find != -1
    # loop util we find the nth or we find no match
    while find != -1 and i != n:
        # find + 1 means we start searching from after the last match
        find = s.find(sub, find + 1)
        i += 1
    # If i is equal to n we found nth match so replace
    if i == n:
        return s[:find] + repl + s[find+len(sub):]
    return s

images_dir = './maps/brawler_images'
images_path = os.listdir(images_dir)
gamemodes_dir = './maps/gamemode_images'

images = {}
for image in images_path:
    images[clean_brawler_name(image.replace('.png',''))] = os.path.join(images_dir, image)
    
list_of_gamemodes = df['gamemodes']

for gamemode in list_of_gamemodes:
    fname = gamemode.replace(' ','-')+'.png'
    images[gamemode] = os.path.join(gamemodes_dir, fname)
    
columns = [str(x) for x in list(range(1,best_brawlers+1))]
    
df[columns] = df['best_brawlers'].str.split(', ', best_brawlers-1, expand=True)

def path_to_image_html(path):
    return '<img src="'+ path + '" width="60" >'
    
def path_to_image_html_smaller(path):
    return '<img src="'+ path + '" width="50" >'

format_dict = {}
for image_col in columns+['gamemodes']:
    if image_col=='gamemodes':
        format_dict[image_col] = path_to_image_html_smaller
    else:
        format_dict[image_col] = path_to_image_html
        
for col in columns+['gamemodes']:
    df[col] = df[col].map(images)

df = df.drop(['best_brawlers'],axis=1)
df['win_rates'] = df['win_rates'].map(clean_string)
df['win_rates'] = df['win_rates'].map(round_string)
df['win_rates'] = df['win_rates'].map(lambda s: nth_repl(s, ", ","<br>",4))
df['use_rates'] = df['use_rates'].map(clean_string)
df['use_rates'] = df['use_rates'].map(lambda s: nth_repl(s, ", ","<br>",4))
df = df[['gamemodes','map']+columns+['win_rates','use_rates']]
df.index += 1
# df.to_html('best_brawlers.html', escape=False, formatters=format_dict, render_links=True)

# %%
df2 = df.fillna('   ').head(9)
HTML(df2.to_html(escape=False, formatters=format_dict))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>gamemodes</th>
#       <th>map</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>win_rates</th>
#       <th>use_rates</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td><img src="./maps/gamemode_images/Bounty.png" width="50" ></td>
#       <td>Shooting Star</td>
#       <td><img src="./maps/brawler_images/Bonnie.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Nani.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Eve.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Sprout.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Max.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Mr.P.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Piper.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Gene.png" width="60" ></td>
#       <td>62, 60, 60, 60<br>59, 57, 55, 55</td>
#       <td>1.3, 9.2, 3.4, 2.2<br>2.5, 1.3, 18.3, 2.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src="./maps/gamemode_images/Bounty.png" width="50" ></td>
#       <td>Canal Grande</td>
#       <td><img src="./maps/brawler_images/Bonnie.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Janet.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Eve.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Rosa.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Mr.P.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Squeak.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Sandy.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Spike.png" width="60" ></td>
#       <td>67, 67, 65, 63<br>63, 59, 58, 58</td>
#       <td>1.5, 2.3, 2.1, 2.1<br>2.4, 3.0, 1.2, 2.1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src="./maps/gamemode_images/Bounty.png" width="50" ></td>
#       <td>Snake Prairie</td>
#       <td><img src="./maps/brawler_images/Eve.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Janet.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Rosa.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Tara.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Mr.P.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Emz.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Jacky.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Crow.png" width="60" ></td>
#       <td>71, 63, 59, 57<br>56, 56, 55, 54</td>
#       <td>6.9, 2.3, 8.8, 9.3<br>1.9, 3.7, 1.6, 2.3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><img src="./maps/gamemode_images/Brawl-Ball.png" width="50" ></td>
#       <td>Super Beach</td>
#       <td><img src="./maps/brawler_images/Bonnie.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Jacky.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Ash.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Janet.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Sandy.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Bea.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Nita.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Griff.png" width="60" ></td>
#       <td>65, 62, 61, 58<br>58, 58, 57, 57</td>
#       <td>1.6, 1.6, 1.2, 1.3<br>2.3, 2.3, 1.5, 1.8</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><img src="./maps/gamemode_images/Brawl-Ball.png" width="50" ></td>
#       <td>Pinhole Punt</td>
#       <td><img src="./maps/brawler_images/Bonnie.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Janet.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Sandy.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Eve.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Crow.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Emz.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Tara.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Frank.png" width="60" ></td>
#       <td>67, 62, 60, 59<br>57, 57, 56, 56</td>
#       <td>2.9, 1.7, 1.9, 1.2<br>4.3, 2.5, 3.4, 2.7</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td><img src="./maps/gamemode_images/Brawl-Ball.png" width="50" ></td>
#       <td>Sneaky Fields</td>
#       <td><img src="./maps/brawler_images/Bonnie.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Jacky.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Rosa.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Ash.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Emz.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Griff.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Sandy.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Janet.png" width="60" ></td>
#       <td>63, 61, 60, 59<br>58, 58, 58, 58</td>
#       <td>1.4, 3.1, 3.4, 1.8<br>2.9, 1.9, 2.0, 1.2</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td><img src="./maps/gamemode_images/Gem-Grab.png" width="50" ></td>
#       <td>Hard Rock Mine</td>
#       <td><img src="./maps/brawler_images/Colonel-Ruffs.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Ash.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Janet.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Eve.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Rosa.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Max.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/8-Bit.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Bull.png" width="60" ></td>
#       <td>62, 62, 60, 59<br>57, 57, 56, 56</td>
#       <td>1.6, 1.5, 1.5, 1.9<br>2.9, 1.5, 1.4, 1.1</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td><img src="./maps/gamemode_images/Gem-Grab.png" width="50" ></td>
#       <td>Chill Space</td>
#       <td><img src="./maps/brawler_images/Eve.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Colonel-Ruffs.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Ash.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Janet.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Sandy.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Tara.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Spike.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Bo.png" width="60" ></td>
#       <td>81, 80, 78, 78<br>76, 74, 74, 73</td>
#       <td>5.1, 1.8, 2.2, 3.2<br>3.1, 4.9, 2.7, 4.7</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><img src="./maps/gamemode_images/Gem-Grab.png" width="50" ></td>
#       <td>Double Swoosh</td>
#       <td><img src="./maps/brawler_images/Janet.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Eve.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Ash.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Rosa.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Sandy.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Pam.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Crow.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Tara.png" width="60" ></td>
#       <td>63, 59, 59, 58<br>57, 57, 56, 55</td>
#       <td>2.2, 1.9, 1.3, 3.4<br>4.2, 1.8, 5.6, 8.6</td>
#     </tr>
#   </tbody>
# </table>

# %%
df3 = df.fillna('   ').tail(9)
HTML(df3.to_html(escape=False, formatters=format_dict))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>gamemodes</th>
#       <th>map</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>win_rates</th>
#       <th>use_rates</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>10</th>
#       <td><img src="./maps/gamemode_images/Heist.png" width="50" ></td>
#       <td>Hot Potato</td>
#       <td><img src="./maps/brawler_images/Rico.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Emz.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Buzz.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Bull.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Bibi.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Darryl.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Nita.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Griff.png" width="60" ></td>
#       <td>75, 60, 59, 58<br>58, 58, 57, 56</td>
#       <td>9.8, 7.6, 1.5, 6.8<br>11.4, 3.7, 3.0, 1.8</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td><img src="./maps/gamemode_images/Heist.png" width="50" ></td>
#       <td>Safe Zone</td>
#       <td><img src="./maps/brawler_images/Bonnie.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Eve.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Bibi.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Max.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Rico.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Colette.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Lola.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Darryl.png" width="60" ></td>
#       <td>69, 65, 63, 60<br>60, 59, 59, 57</td>
#       <td>1.2, 4.6, 1.8, 1.2<br>7.7, 4.1, 1.4, 2.1</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td><img src="./maps/gamemode_images/Heist.png" width="50" ></td>
#       <td>Cant touch this</td>
#       <td><img src="./maps/brawler_images/Bonnie.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Bea.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Crow.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Griff.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Darryl.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Lola.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Bibi.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Tara.png" width="60" ></td>
#       <td>66, 66, 65, 62<br>62, 60, 60, 60</td>
#       <td>1.5, 1.6, 1.8, 2.7<br>2.2, 1.6, 7.4, 1.9</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td><img src="./maps/gamemode_images/Hot-Zone.png" width="50" ></td>
#       <td>Ring of Fire</td>
#       <td><img src="./maps/brawler_images/Janet.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Bonnie.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Colonel-Ruffs.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Pam.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Eve.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Sandy.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Poco.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Lola.png" width="60" ></td>
#       <td>65, 64, 63, 62<br>60, 60, 59, 59</td>
#       <td>1.6, 1.4, 1.1, 3.3<br>4.0, 2.5, 7.5, 1.8</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td><img src="./maps/gamemode_images/Hot-Zone.png" width="50" ></td>
#       <td>Dueling Beetles</td>
#       <td><img src="./maps/brawler_images/Griff.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Penny.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Lola.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Bonnie.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Meg.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Leon.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Stu.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Bea.png" width="60" ></td>
#       <td>100, 90, 81, 72<br>65, 65, 64, 64</td>
#       <td>7.4, 10.3, 5.4, 1.8<br>2.0, 1.8, 2.5, 1.3</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td><img src="./maps/gamemode_images/Hot-Zone.png" width="50" ></td>
#       <td>Open Zone</td>
#       <td><img src="./maps/brawler_images/Janet.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Bonnie.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Lola.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Pam.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Amber.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Crow.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Meg.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Eve.png" width="60" ></td>
#       <td>74, 72, 71, 68<br>65, 64, 64, 64</td>
#       <td>3.3, 2.8, 3.3, 2.8<br>2.5, 9.4, 1.3, 3.3</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td><img src="./maps/gamemode_images/Knockout.png" width="50" ></td>
#       <td>Belles Rock</td>
#       <td><img src="./maps/brawler_images/Bonnie.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Janet.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Eve.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Leon.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Mr.P.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Gene.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Sprout.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Colonel-Ruffs.png" width="60" ></td>
#       <td>68, 62, 60, 60<br>59, 59, 59, 58</td>
#       <td>3.9, 2.4, 2.2, 3.3<br>2.5, 6.7, 5.8, 16.7</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td><img src="./maps/gamemode_images/Knockout.png" width="50" ></td>
#       <td>Goldarm Gulch</td>
#       <td><img src="./maps/brawler_images/Gene.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Tara.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Colonel-Ruffs.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Amber.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Emz.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Sprout.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Gale.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Rico.png" width="60" ></td>
#       <td>58, 56, 55, 55<br>55, 54, 54, 54</td>
#       <td>3.6, 4.9, 1.5, 1.7<br>2.9, 2.9, 5.0, 8.8</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td><img src="./maps/gamemode_images/Knockout.png" width="50" ></td>
#       <td>X Marks the Spot</td>
#       <td><img src="./maps/brawler_images/Bonnie.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Janet.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Eve.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Grom.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Mr.P.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Gene.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Nani.png" width="60" ></td>
#       <td><img src="./maps/brawler_images/Sprout.png" width="60" ></td>
#       <td>69, 65, 61, 60<br>60, 59, 59, 57</td>
#       <td>8.3, 3.3, 3.6, 1.1<br>1.7, 2.2, 2.5, 1.7</td>
#     </tr>
#   </tbody>
# </table>

# %%
df
# Out:
#      gamemodes               map                           best_brawlers  \
# 0       Bounty     Shooting Star          Bonnie, Nani, Eve, Sprout, Max
# 1       Bounty      Canal Grande         Bonnie, Janet, Eve, Rosa, Mr. P
# 2       Bounty     Snake Prairie           Eve, Janet, Rosa, Tara, Mr. P
# 3   Brawl Ball       Super Beach        Bonnie, Jacky, Ash, Janet, Sandy
# 4   Brawl Ball      Pinhole Punt         Bonnie, Janet, Sandy, Eve, Crow
# 5   Brawl Ball     Sneaky Fields           Bonnie, Jacky, Rosa, Ash, Emz
# 6     Gem Grab    Hard Rock Mine    Colonel Ruffs, Ash, Janet, Eve, Rosa
# 7     Gem Grab       Chill Space   Eve, Colonel Ruffs, Ash, Janet, Sandy
# 8     Gem Grab     Double Swoosh            Janet, Eve, Ash, Rosa, Sandy
# 9        Heist        Hot Potato             Rico, Emz, Buzz, Bull, Bibi
# 10       Heist         Safe Zone            Bonnie, Eve, Bibi, Max, Rico
# 11       Heist   Cant touch this        Bonnie, Bea, Crow, Griff, Darryl
# 12    Hot Zone      Ring of Fire  Janet, Bonnie, Colonel Ruffs, Pam, Eve
# 13    Hot Zone   Dueling Beetles         Griff, Penny, Lola, Bonnie, Meg
# 14    Hot Zone         Open Zone         Janet, Bonnie, Lola, Pam, Amber
# 15    Knockout       Belles Rock         Bonnie, Janet, Eve, Leon, Mr. P
# 16    Knockout     Goldarm Gulch   Gene, Tara, Colonel Ruffs, Amber, Emz
# 17    Knockout  X Marks the Spot         Bonnie, Janet, Eve, Grom, Mr. P
#
#                              win_rates                      use_rates
# 0    62.6%, 60.8%, 60.7%, 60.4%, 59.1%   1.3%, 9.2%, 3.4%, 2.2%, 2.5%
# 1    67.6%, 67.0%, 65.4%, 63.9%, 63.2%   1.5%, 2.3%, 2.1%, 2.1%, 2.4%
# 2    71.4%, 63.0%, 59.2%, 57.1%, 56.8%   6.9%, 2.3%, 8.8%, 9.3%, 1.9%
# 3    65.1%, 62.8%, 61.3%, 58.6%, 58.1%   1.6%, 1.6%, 1.2%, 1.3%, 2.3%
# 4    67.3%, 62.9%, 60.1%, 59.2%, 57.5%   2.9%, 1.7%, 1.9%, 1.2%, 4.3%
# 5    63.4%, 61.1%, 60.2%, 59.7%, 58.4%   1.4%, 3.1%, 3.4%, 1.8%, 2.9%
# 6    62.9%, 62.3%, 60.6%, 59.3%, 57.9%   1.6%, 1.5%, 1.5%, 1.9%, 2.9%
# 7    81.9%, 80.1%, 78.6%, 78.4%, 76.1%   5.1%, 1.8%, 2.2%, 3.2%, 3.1%
# 8    63.2%, 59.6%, 59.4%, 58.0%, 57.7%   2.2%, 1.9%, 1.3%, 3.4%, 4.2%
# 9    75.0%, 60.1%, 59.6%, 58.6%, 58.5%  9.8%, 7.6%, 1.5%, 6.8%, 11.4%
# 10   69.4%, 65.2%, 63.3%, 60.7%, 60.3%   1.2%, 4.6%, 1.8%, 1.2%, 7.7%
# 11   66.9%, 66.0%, 65.3%, 62.6%, 62.3%   1.5%, 1.6%, 1.8%, 2.7%, 2.2%
# 12   65.7%, 64.6%, 63.7%, 62.0%, 60.7%   1.6%, 1.4%, 1.1%, 3.3%, 4.0%
# 13  100.0%, 90.9%, 81.8%, 72.0%, 65.7%  7.4%, 10.3%, 5.4%, 1.8%, 2.0%
# 14   74.9%, 72.1%, 71.8%, 68.8%, 65.1%   3.3%, 2.8%, 3.3%, 2.8%, 2.5%
# 15   68.9%, 62.4%, 60.5%, 60.1%, 59.5%   3.9%, 2.4%, 2.2%, 3.3%, 2.5%
# 16   58.7%, 56.3%, 55.6%, 55.6%, 55.1%   3.6%, 4.9%, 1.5%, 1.7%, 2.9%
# 17   69.4%, 65.3%, 61.0%, 60.8%, 60.1%   8.3%, 3.3%, 3.6%, 1.1%, 1.7%
